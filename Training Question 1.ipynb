# %% [markdown]
# # Training Question Phase I

# %% [markdown]
# ## 信仰

# %% [markdown]
# ### 为什么大家这么想学Python?是因为格调高？领导下令？朋友感化？转行为996的程序员？爬图爬剧爬电影？量化分析？距离人工智能近了一步的错觉?

# %% [markdown]
# ## 安装与配置

# %% [markdown]
# ### 目前(2019-07)Python应该安装什么版本？32位还是64位？

# %% [markdown]
# ### 通过什么工具安装Python组件？

# %% [markdown]
# ### 列举几个你所熟悉的Python组件包

# %% [markdown]
# ### 如果安装Python组件的时候，提示：ERROR MICROSOFT VISUAL C++ 14.0 IS REQUIRED，应该如何解决？

# %% [markdown]
# ### 可以从哪里获取Python的优秀项目？

# %% [markdown]
# ### 列举几种编写Python的编辑器或项目开发环境

# %% [markdown]
# ## 基础

# %% [markdown]
# ### Python3的源代码的默认编码？

# %% [markdown]
# ### 以下变量声明，哪些是错误的？

# %%
π送 = 123

# %%
1周目 = 'easy'
# Out:
#   File "<ipython-input-6-ecfff35d7e40>", line 1
#     1周目 = 'easy'
#       ^
# SyntaxError: invalid syntax

# %%
False = 'good'
# Out:
#   File "<ipython-input-8-5a828f9b4c98>", line 1
#     False = 'good'
#                   ^
# SyntaxError: can't assign to keyword

# %%
ar_data = True

# %% [markdown]
# ### 有哪些方式注释下面的代码？

# %%
# code = '注释我'
'''
count = 1
while True:
    count += 1
    if count > 5:
        break
'''
# Out:
# '\ncount = 1\nwhile True:\n    count += 1\n    if count > 5:\n        break\n'

# %% [markdown]
# ### Python通过什么方式表示代码层级？是大括号，小括号还是中括号？或者都不是？

# %% [markdown]
# ### 什么情况下，不需要在换行后面加\？

# %% [markdown]
# ### 如何查看对象的数据类型？

# %%
iamnumber = 0

# %%
type(iamnumber)
# Out:
# int

# %% [markdown]
# ### 如何表示字符串定义？举例单行与多行

# %% [markdown]
# ### 字符串中的转义符是什么？如何使得字符串中的转义符失效？

# %% [markdown]
# ### Python有char类型么？如何从字符串获得一个特定位置的字符？

# %% [markdown]
# ### Python列表中，第一个成员的索引是什么？最后一个索引的成员是什么？

# %% [markdown]
# ###
